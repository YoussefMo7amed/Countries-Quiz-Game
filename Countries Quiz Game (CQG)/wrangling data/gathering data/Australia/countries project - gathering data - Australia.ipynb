# %%
import os
import requests as req
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ## gathering data from url

# %%
url = 'https://affairscloud.com/australia-continent-countries-capitals-currency-code/'
res = req.get(url)
res
# Out:
# <Response [200]>

# %%
with open(os.path.join('Australia.html'), mode = 'wb') as file:
    file.write(res.content)

# %% [markdown]
# ## getting data using Beautiful Soup

# %% [markdown]
# getting head

# %%
columns = []
with open('Australia.html') as file:
    soup = bs(file)
    table = soup.find('table')
    head = table.find_all('th')
    for col in head:
        columns.append(str(col).strip()[4:-5])
columns
# Out:
# ['Name', 'Capital', 'Currency', 'Official language']

# %%
columns[0] = 'Country'

# %%
columns
# Out:
# ['Country', 'Capital', 'Currency', 'Official language']

# %%
df = pd.DataFrame(columns=columns)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Country, Capital, Currency, Official language]
# Index: []

# %%
with open('Australia.html') as file:
    soup = bs(file,'lxml')
    table = soup.find('tbody')
    rows = table.find_all('tr')
    for i in range(1,len(rows)):
        row = rows[i].find_all('td')
        values = []
        for value in row:
            s = str(value).strip()[4:-5]
            s = s.replace('<br/>',', ')
            s = s.replace('\n','')
            values.append(s)
        df = df.append(dict(zip(columns,values)), ignore_index=True)

# %%
df
# Out:
#                         Country  \
# 0                American Samoa
# 1   Ashmore and Cartier Islands
# 2                     Australia
# 3                  Baker Island
# 4                  Cook Islands
# 5             Coral Sea Islands
# 6                          Fiji
# 7              French Polynesia
# 8                          Guam
# 9                Howland Island
# 10                Jarvis Island
# 11               Johnston Atoll
# 12                 Kingman Reef
# 13                     Kiribati
# 14             Marshall Islands
# 15                   Micronesia
# 16                 Midway Atoll
# 17                        Nauru
# 18                New Caledonia
# 19                  New Zealand
# 20                         Niue
# 21               Norfolk Island
# 22     Northern Mariana Islands
# 23                        Palau
# 24                Palmyra Atoll
# 25             Papua New Guinea
# 26             Pitcairn Islands
# 27                        Samoa
# ...

# %% [markdown]
# ## save data

# %%
df.to_csv('Australia.csv', index= False)
